# %% [markdown]
# # **🗃️ Data Lab**

# %% [markdown]
# Useful dataset: [Mall customers dataset](https://drive.google.com/file/d/1jACghC-it0Hlb091tc2BH_RgrFWOXXih/view?usp=sharing)

# %% [markdown]
# ## Load a dataset 📑

# %%
### 🔼 Upload your file (first)

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")


file_path = _
data = pd.read_csv(file_path)

var_h = " _ "
var_v = " _ "
labels = ""

_, ax = plt.subplots (figsize=(5,4))
sns.scatterplot(ax = ax, data = _ ,x = _ ,y = _ , hue = labels if labels != "" else None, palette='colorblind')
print ("\nData Loaded! ✅")
print (" - Shape: {0}\n".format( _ ))

# %%
# normalize / Standardize data
from sklearn.preprocessing import StandardScaler

X = StandardScaler().fit_transform( _ )

print (X.shape)

# %% [markdown]
# # **📋 Model Lab**

# %%
# Import and instance model
from sklearn.cluster import KMeans

n_clusters = 2
model = KMeans(n_clusters=n_clusters, random_state=4)

# %%
model.fit( _ )

print ("\nTraining done! ✅")

# %%
# make predictions
predictions = _

_, ax = plt.subplots(figsize=(5,4))
ax.set_title(" KMeans ")

ax.scatter( _ , _ , c =  _ , edgecolors='k')
print ("Plots... \n")
# Out:
# Plots...
